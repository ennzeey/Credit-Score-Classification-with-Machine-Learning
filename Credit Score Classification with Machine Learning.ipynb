# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option('display.float_format', lambda x: '%.3f' % x)
sns.set_style('whitegrid')

# %%
df = pd.read_csv('train.csv')

# %% [markdown]
# # EDA

# %%
df.head()
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635         3392      2  Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636         3392      3  Aaron Maashoh  23.0  821000265.0  Scientist
# 3  5637         3392      4  Aaron Maashoh  23.0  821000265.0  Scientist
# 4  5638         3392      5  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0       19114.12            1824.843333                3.0  ...        Good
# 1       19114.12            1824.843333                3.0  ...        Good
# 2       19114.12            1824.843333                3.0  ...        Good
# 3       19114.12            1824.843333                3.0  ...        Good
# 4       19114.12            1824.843333                3.0  ...        Good
#
#    Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  int64
#  1   Customer_ID               100000 non-null  int64
#  2   Month                     100000 non-null  int64
#  3   Name                      100000 non-null  object
#  4   Age                       100000 non-null  float64
#  5   SSN                       100000 non-null  float64
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  float64
#  8   Monthly_Inhand_Salary     100000 non-null  float64
#  9   Num_Bank_Accounts         100000 non-null  float64
#  10  Num_Credit_Card           100000 non-null  float64
#  11  Interest_Rate             100000 non-null  float64
#  12  Num_of_Loan               100000 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# ID                          0
# Customer_ID                 0
# Month                       0
# Name                        0
# Age                         0
# SSN                         0
# Occupation                  0
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Type_of_Loan                0
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Payment_Behaviour           0
# Monthly_Balance             0
# Credit_Score                0
# dtype: int64

# %%
df.describe()
# Out:
#                   ID    Customer_ID          Month            Age  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean    80631.500000   25982.666640       4.500000      33.316340
# std     43301.486619   14340.543051       2.291299      10.764812
# min      5634.000000    1006.000000       1.000000      14.000000
# 25%     43132.750000   13664.500000       2.750000      24.000000
# 50%     80631.500000   25777.000000       4.500000      33.000000
# 75%    118130.250000   38385.000000       6.250000      42.000000
# max    155629.000000   50999.000000       8.000000      56.000000
#
#                 SSN  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count  1.000000e+05  100000.000000          100000.000000      100000.000000
# mean   5.004617e+08   50505.123449            4197.270835           5.368820
# std    2.908267e+08   38299.422093            3186.432497           2.593314
# ...

# %%
df['Customer_ID'].value_counts()
# Out:
# 2049     8
# 5736     8
# 9646     8
# 11695    8
# 50610    8
#         ..
# 43968    8
# 33733    8
# 50125    8
# 15314    8
# 8188     8
# Name: Customer_ID, Length: 12500, dtype: int64

# %%
df[df['Customer_ID']==2049]
# Out:
#            ID  Customer_ID  Month    Name   Age          SSN  Occupation  \
# 76064  119730         2049      1  Naomiv  28.0  478457247.0  Accountant
# 76065  119731         2049      2  Naomiv  28.0  478457247.0  Accountant
# 76066  119732         2049      3  Naomiv  28.0  478457247.0  Accountant
# 76067  119733         2049      4  Naomiv  29.0  478457247.0  Accountant
# 76068  119734         2049      5  Naomiv  29.0  478457247.0  Accountant
# 76069  119735         2049      6  Naomiv  29.0  478457247.0  Accountant
# 76070  119736         2049      7  Naomiv  29.0  478457247.0  Accountant
# 76071  119737         2049      8  Naomiv  29.0  478457247.0  Accountant
#
#        Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 76064       37182.62            3200.551667                7.0  ...
# 76065       37182.62            3200.551667                7.0  ...
# 76066       37182.62            3200.551667                7.0  ...
# ...

# %%
occupation_By_Income = df.groupby('Occupation')['Annual_Income'].sum().sort_values(ascending=False)

# %%
plt.figure(figsize=(17,8))
print(occupation_By_Income)
sns.barplot(x=occupation_By_Income.index, y=occupation_By_Income.values,data=df,palette='hls')
plt.title('Occupation by Annual Income', fontsize=17)
plt.xlabel('Occupation', fontsize=15)
plt.ylabel('Income',fontsize = 12)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.tight_layout()
# Out:
# Occupation
# Architect       353997677.040
# Lawyer          351920566.640
# Engineer        348215209.560
# Scientist       345268708.440
# Accountant      342096956.520
# Media_Manager   340155898.600
# Mechanic        339444448.760
# Entrepreneur    338966217.480
# Developer       336862996.800
# Teacher         332699540.600
# Manager         331034250.600
# Musician        326273810.480
# Doctor          325232581.840
# Writer          321804423.640
# Journalist      316539057.880
# Name: Annual_Income, dtype: float64

# %% [markdown]
# Architects ranks the highest by Annual Income

# %%
plt.figure(figsize=(17,8))
print(df['Credit_Score'].value_counts())
sns.countplot(x ='Credit_Score',data=df)
plt.title('Credit Score distribution',fontsize=17)
plt.xlabel('Credit Score', fontsize=17)
plt.ylabel('Volume', fontsize=17)
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 12)
# Out:
# Standard    53174
# Poor        28998
# Good        17828
# Name: Credit_Score, dtype: int64
# (array([    0., 10000., 20000., 30000., 40000., 50000., 60000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
df.head()
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635         3392      2  Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636         3392      3  Aaron Maashoh  23.0  821000265.0  Scientist
# 3  5637         3392      4  Aaron Maashoh  23.0  821000265.0  Scientist
# 4  5638         3392      5  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0       19114.12            1824.843333                3.0  ...        Good
# 1       19114.12            1824.843333                3.0  ...        Good
# 2       19114.12            1824.843333                3.0  ...        Good
# 3       19114.12            1824.843333                3.0  ...        Good
# 4       19114.12            1824.843333                3.0  ...        Good
#
#    Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# ...

# %%
plt.figure(figsize=(19,10))
sns.countplot(x ='Occupation',data=df,hue='Credit_Score')
plt.title('Occupation by Credit Score ',fontsize = 17)
plt.xlabel('Occupation',fontsize=17)
plt.ylabel('Volume',fontsize=17)
plt.xticks(rotation=90)
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 12)
# Out:
# (array([   0.,  500., 1000., 1500., 2000., 2500., 3000., 3500., 4000.,
#         4500.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# Lawyers basically have the highest number of 'Standard' in Credit Score

# %%
df.Payment_Behaviour.value_counts().sort_values(ascending=False)
# Out:
# Low_spent_Small_value_payments      28616
# High_spent_Medium_value_payments    19738
# High_spent_Large_value_payments     14726
# Low_spent_Medium_value_payments     14399
# High_spent_Small_value_payments     11764
# Low_spent_Large_value_payments      10757
# Name: Payment_Behaviour, dtype: int64

# %%
CreditScore_by_Income = df.groupby('Credit_Score')['Annual_Income'].sum()

# %%
plt.figure(figsize=(19,10))

sns.boxplot(x='Credit_Score',y='Annual_Income',data=df,palette='rocket')
plt.title('Credit Score by Annual Income',fontsize=17)
plt.xlabel('Credit Score',fontsize=17)
plt.ylabel('Annual Income', fontsize=17)
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 12)
# Out:
# (array([-25000.,      0.,  25000.,  50000.,  75000., 100000., 125000.,
#         150000., 175000., 200000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
df.head()
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635         3392      2  Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636         3392      3  Aaron Maashoh  23.0  821000265.0  Scientist
# 3  5637         3392      4  Aaron Maashoh  23.0  821000265.0  Scientist
# 4  5638         3392      5  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0       19114.12            1824.843333                3.0  ...        Good
# 1       19114.12            1824.843333                3.0  ...        Good
# 2       19114.12            1824.843333                3.0  ...        Good
# 3       19114.12            1824.843333                3.0  ...        Good
# 4       19114.12            1824.843333                3.0  ...        Good
#
#    Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# ...

# %%
plt.figure(figsize=(19,10))

sns.boxplot(x='Credit_Score',y='Monthly_Inhand_Salary',data=df,palette='crest')
plt.title('Credit Score by Monthly Inhand Salary',fontsize=17)
plt.xlabel('Credit Score',fontsize=17)
plt.ylabel('Monthly Inhand Salary', fontsize=17)
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 12)
# Out:
# (array([-2000.,     0.,  2000.,  4000.,  6000.,  8000., 10000., 12000.,
#         14000., 16000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure(figsize=(19,10))

sns.barplot(x='Credit_Score',y='Num_Bank_Accounts',data=df,palette='magma')
plt.title('Credit Score by Num of Bank Accounts',fontsize=17)
plt.xlabel('Credit Score',fontsize=17)
plt.ylabel('Bank Accounts Num', fontsize=17)
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 12)
# Out:
# (array([0., 1., 2., 3., 4., 5., 6., 7.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
df.columns
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
plt.figure(figsize=(19,10))

sns.boxplot(x='Credit_Score',y='Num_Credit_Card',data=df,palette='viridis')
plt.title('Credit Score by Num of Credit Cards',fontsize=17)
plt.xlabel('Credit Score',fontsize=17)
plt.ylabel('Credit Card  Num', fontsize=17)
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 12)
# Out:
# (array([-2.,  0.,  2.,  4.,  6.,  8., 10., 12.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure(figsize=(19,10))

sns.boxplot(x='Credit_Score',y='Interest_Rate',data=df,palette='cubehelix')
plt.title('Credit Score by Interest Rate',fontsize=17)
plt.xlabel('Credit Score',fontsize=17)
plt.ylabel('Interest Rate', fontsize=17)
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 12)
# Out:
# (array([-5.,  0.,  5., 10., 15., 20., 25., 30., 35., 40.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure(figsize=(19,10))

sns.boxplot(x='Credit_Score',y='Num_of_Loan',data=df,palette=
            {'Poor':'red','Standard':'yellow','Good':'green'})
plt.title('Credit Score by Number of Loan taking by an individual',fontsize=17)
plt.xlabel('Credit Score',fontsize=12)
plt.ylabel('Number of loan ', fontsize=12)
#plt.xticks(fontsize = 10)
#plt.yticks(fontsize = 10)
# Out:
# Text(0, 0.5, 'Number of loan ')

# %% [markdown]
# To have a good credit score, you should not take more than 1 – 3 loans at a time. Having more than three loans at a time will negatively impact your credit scores.

# %%
df.columns
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
plt.figure(figsize=(19,10))

sns.boxplot(x='Credit_Score',y='Delay_from_due_date',data=df,palette=
            {'Poor':'red','Standard':'yellow','Good':'green'})
plt.title('Credit Score by delayed number of days for credit card payment',fontsize=17)
plt.xlabel('Credit Score',fontsize=17)
plt.ylabel('Delay_from_due_date ', fontsize=17)
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 12)
# Out:
# (array([-10.,   0.,  10.,  20.,  30.,  40.,  50.,  60.,  70.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# you can delay your credit card payment 5 – 14 days from the due date. Delaying your payments for more than 17 days from the due date will impact your credit scores negatively.

# %%
plt.figure(figsize=(19,10))

sns.boxplot(x='Credit_Score',y='Num_of_Delayed_Payment',data=df,palette=
            {'Poor':'red','Standard':'yellow','Good':'green'})
plt.title('Credit Score by Number of Delayed Payment',fontsize=17)
plt.xlabel('Credit Score',fontsize=17)
plt.ylabel('Number of Delayed Payment ', fontsize=17)
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 12)
# Out:
# (array([-5.,  0.,  5., 10., 15., 20., 25., 30.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# Delaying 4 – 12 payments from the due date will not affect your credit scores. But delaying more than 12 payments from the due date will affect your credit scores negatively.

# %%
plt.figure(figsize=(19,10))

sns.boxplot(x='Credit_Score',y='Outstanding_Debt',data=df,palette=
            {'Poor':'red','Standard':'yellow','Good':'green'})
plt.title('Credit Score Based on Outstanding Debt',fontsize=17)
plt.xlabel('Credit Score',fontsize=17)
plt.ylabel('Outstanding_Debt ', fontsize=17)
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 12)
# Out:
# (array([-1000.,     0.,  1000.,  2000.,  3000.,  4000.,  5000.,  6000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# An outstanding debt of $350 - $1200 will not affect your credit scores. but if you have more debt that is > $1500 it will begin to affect your  credit score

# %%
plt.figure(figsize=(19,10))

sns.boxplot(x='Credit_Score',y='Amount_invested_monthly',data=df,palette=
            {'Poor':'red','Standard':'yellow','Good':'green'})
plt.title('Credit Score by Amount Invested Monthly ',fontsize=17)
plt.xlabel('Credit Score',fontsize=17)
plt.ylabel('Amount Invested Monthly ', fontsize=17)
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 12)
# Out:
# (array([-100.,    0.,  100.,  200.,  300.,  400.,  500.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# The amount of money you invest monthly doesn’t affect your credit scores a lot. Now let’s see if having a low amount at the end of the month affects credit scores or not

# %%
plt.figure(figsize=(19,10))

sns.boxplot(x='Credit_Score',y='Monthly_Balance',data=df,palette=
            {'Poor':'red','Standard':'yellow','Good':'green'})
plt.title('Credit Score by Monthly Balance ',fontsize=17)
plt.xlabel('Credit Score',fontsize=17)
plt.ylabel('Monthly_Balance ', fontsize=17)
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 12)
# Out:
# (array([-200.,    0.,  200.,  400.,  600.,  800., 1000., 1200., 1400.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# Having a high monthly balance in your account at the end of the month is good for your credit scores. A monthly balance of less than $250 is bad for credit scores.

# %% [markdown]
# ## Credit Score Classification Model

# %%
# Lets do some feature engineering by converting "Credit Mix" column into numerical so it can be used in our ml model"

#mix = {'Standard':1,'Good':2,'Bad':0}

df['Credit_Mix'] = df['Credit_Mix'].map({"Standard":1,"Good":2,"Bad":0})

from sklearn.model_selection import train_test_split

# %%
df.head()
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635         3392      2  Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636         3392      3  Aaron Maashoh  23.0  821000265.0  Scientist
# 3  5637         3392      4  Aaron Maashoh  23.0  821000265.0  Scientist
# 4  5638         3392      5  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0       19114.12            1824.843333                3.0  ...           2
# 1       19114.12            1824.843333                3.0  ...           2
# 2       19114.12            1824.843333                3.0  ...           2
# 3       19114.12            1824.843333                3.0  ...           2
# 4       19114.12            1824.843333                3.0  ...           2
#
#    Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
df.Age.max()
# Out:
# 56.0

# %%
bins = [0,18,25,35,45,55,float('inf')]
labels = ['0-18','19-25','26-35','36-45','46-55','56+']
df['Age_Range'] = pd.cut(df['Age'],bins=bins,labels=labels)

# %%
sns.countplot(x='Age_Range', data=df, hue= "Credit_Score", palette={'Poor': 'red','Standard':'yellow','Good':'green'})

plt.figure(figsize=(17,8))
plt.title('Age distribution by Credit Score',fontsize=17)
plt.xlabel('Age Range',fontsize=12)
plt.ylabel('volume')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
# Out:
# <AxesSubplot:title={'center':'Age distribution by Credit Score'}, xlabel='Age_Range', ylabel='count'>

# %% [markdown]
# Ages between 26-35 got the most people with standard score as well as poor credit score, Ages between 36-45 also as a Good amount of Standard score and a lower poor socre as compared to 26-35

# %%
plt.figure(figsize=(17,9))
sns.boxplot(x='Age_Range',y='Monthly_Inhand_Salary',data=df)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.xlabel('Age Range',fontsize=13)
plt.ylabel('Monthly_Inhand_Salary',fontsize=13)
# Out:
# Text(0, 0.5, 'Monthly_Inhand_Salary')

# %% [markdown]
# Ages between 46-55 has more people with Higer monthly inhand salary

# %%
df[df['Age_Range'] == '0-18']
# Out:
#            ID  Customer_ID  Month             Name  Age        SSN Occupation  \
# 288      6066        16512      1        ra Alperx   16  995378920   Mechanic
# 289      6067        16512      2        ra Alperx   16  995378920   Mechanic
# 290      6068        16512      3        ra Alperx   16  995378920   Mechanic
# 291      6069        16512      4        ra Alperx   16  995378920   Mechanic
# 292      6070        16512      5        ra Alperx   16  995378920   Mechanic
# ...       ...          ...    ...              ...  ...        ...        ...
# 99807  155341         4658      8          Lawderr   17  441261297  Developer
# 99960  155574        14124      1  Lucia Mutikanik   18  340857301     Lawyer
# 99961  155575        14124      2  Lucia Mutikanik   18  340857301     Lawyer
# 99962  155576        14124      3  Lucia Mutikanik   18  340857301     Lawyer
# 99964  155578        14124      5  Lucia Mutikanik   18  340857301     Lawyer
#
# ...

# %%
df['Age'] = df['Age'].round().astype(int)

# %%
df['SSN'] = df['SSN'].round().astype(int)

# %%
X = df[['Annual_Income','Monthly_Inhand_Salary','Num_Bank_Accounts',
       'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan',
       'Delay_from_due_date', 'Num_of_Delayed_Payment', 
       'Outstanding_Debt','Credit_History_Age', 'Monthly_Balance','Total_EMI_per_month','Amount_invested_monthly',"Age"
                 ]]

y= df[['Credit_Score']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X.head()
# Out:
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0      19114.120               1824.843              3.000            4.000
# 1      19114.120               1824.843              3.000            4.000
# 2      19114.120               1824.843              3.000            4.000
# 3      19114.120               1824.843              3.000            4.000
# 4      19114.120               1824.843              3.000            4.000
#
#    Interest_Rate  Num_of_Loan  Delay_from_due_date  Num_of_Delayed_Payment  \
# 0          3.000        4.000                3.000                   7.000
# 1          3.000        4.000                3.000                   4.000
# 2          3.000        4.000                3.000                   7.000
# 3          3.000        4.000                5.000                   4.000
# 4          3.000        4.000                6.000                   4.000
#
# ...

# %% [markdown]
# # Using Logistic Regression Classifier

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report,confusion_matrix

lr_model = LogisticRegression()

# %%
lr_model.fit(X_train,y_train)
# Out:
# C:\Users\eolawoagbo\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\eolawoagbo\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lr_pred = lr_model.predict(X_test)

# %%
print(classification_report(y_test,lr_pred))
# Out:
#               precision    recall  f1-score   support
#
#         Good       0.41      0.05      0.09      5866
#         Poor       0.53      0.34      0.41      9633
#     Standard       0.55      0.82      0.66     17501
#
#     accuracy                           0.54     33000
#    macro avg       0.50      0.40      0.39     33000
# weighted avg       0.52      0.54      0.49     33000

# %% [markdown]
# # Using RandomForest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
# Initialize the model
rfc_model = RandomForestClassifier()

# %%
rfc_model.fit(X_train,y_train)
# Out:
# <ipython-input-68-87dfdd9fc7aa>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rfc_model.fit(X_train,y_train)
# RandomForestClassifier()

# %%
rfc_pred = rfc_model.predict(X_test)

# %%
print(classification_report(y_test,rfc_pred))
# Out:
#               precision    recall  f1-score   support
#
#         Good       0.78      0.76      0.77      5866
#         Poor       0.80      0.83      0.81      9633
#     Standard       0.83      0.81      0.82     17501
#
#     accuracy                           0.81     33000
#    macro avg       0.80      0.80      0.80     33000
# weighted avg       0.81      0.81      0.81     33000

# %% [markdown]
# # Using DecisionTree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
# Initialize the model
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dtree_pred = dtree.predict(X_test)

# %%
print(classification_report(y_test,dtree_pred))
# Out:
#               precision    recall  f1-score   support
#
#         Good       0.71      0.72      0.71      5866
#         Poor       0.76      0.76      0.76      9633
#     Standard       0.78      0.78      0.78     17501
#
#     accuracy                           0.76     33000
#    macro avg       0.75      0.75      0.75     33000
# weighted avg       0.76      0.76      0.76     33000

# %% [markdown]
# ## Let's make a prediction from our model by giving inputs to our model based on the features we used to train the model

# %%
print("Credit Score Prediction : ")
a = float(input("Annual Income: "))
b = float(input("Monthly Inhand Salary: "))
c = float(input("Number of Bank Accounts: "))
d = float(input("Number of Credit cards: "))
e = float(input("Interest Rate: "))
f = float(input("Number of Loans: "))
g = float(input("Number of days delayed by the person: "))
h = float(input("Number of delayed payments: "))
i = float(input("Outstanding Debt: "))
j = float(input("Credit History Age: "))
k = float(input("Monthly Balance: "))
l = float(input("Total_EMI_per_month: "))
m = float(input("Amount_invested_monthly: "))
n = float(input("Age: "))

features = np.array([[a,b,c,d,e,f,g,h,i,j,k,l,m,n]])
print("Predicted Credit Score = ", rfc_model.predict(features))
# Out:
# Credit Score Prediction :
# Annual Income: 30114.12
# Monthly Inhand Salary: 4024.67363
# Number of Bank Accounts: 3
# Number of Credit cards: 2
# Interest Rate: 9
# Number of Loans: 4
# Number of days delayed by the person: 12
# Number of delayed payments: 3
# Outstanding Debt: 300
# Credit History Age: 200
# Monthly Balance: 400
# Total_EMI_per_month: 49.60
# Amount_invested_monthly: 21.47
# Age: 21
# Predicted Credit Score =  ['Good']
